# %% [markdown]
# <a href="https://colab.research.google.com/github/abia200304/Distinct-Vehicle-Flow-Prediction-/blob/main/TCN_PEMS_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !unzip -o /content/my_pems_data.zip
# Out:
# Archive:  /content/my_pems_data.zip
#    creating: my_pems_data/
#   inflating: my_pems_data/pems_station_500011021_flow_04-01-2024_0600_to_04-07-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_04-08-2024_0600_to_04-14-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_04-15-2024_0600_to_04-21-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_04-22-2024_0600_to_04-28-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_04-29-2024_0600_to_05-05-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_05-06-2024_0600_to_05-12-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_05-13-2024_0600_to_05-19-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_05-20-2024_0600_to_05-26-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_05-27-2024_0600_to_06-02-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_06-03-2024_0600_to_06-09-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_06-10-2024_0600_to_06-16-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_06-17-2024_0600_to_06-23-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_06-24-2024_0600_to_06-30-2024_0600.csv
#   inflating: my_pems_data/pems_station_500011021_flow_07-01-2024_0600_to_07-01-2024_2200.csv

# %%
from glob import glob
import pandas as pd
import numpy as np

file_paths = glob('/content/my_pems_data/*.csv')
all_data = []

for file in file_paths:
    try:
        df = pd.read_csv(file, delimiter='\t')
        df.columns = df.columns.str.strip()
        if 'Flow (Veh/5 Minutes)' in df.columns and 'Truck Flow (Veh/5 Minutes)' in df.columns:
            all_data.append(df[['Flow (Veh/5 Minutes)', 'Truck Flow (Veh/5 Minutes)']])
        else:
            print(f"Skipping {file}: Required columns not found")
    except Exception as e:
        print(f"Error reading {file}: {e}")

# %%
combined_df = pd.concat(all_data, ignore_index=True)
print(combined_df.shape)
# Out:
# (22824, 2)

# %%
def process_traffic_data(df):

    processed_df = df.copy()

    processed_df = processed_df.rename(columns={
        'Flow (Veh/5 Minutes)': 'total_flow',
        'Truck Flow (Veh/5 Minutes)': 'truck_flow'
    })

    if 'total_flow' not in processed_df.columns or 'truck_flow' not in processed_df.columns:
        print("Error: Renaming of columns failed. Check original column names.")
        return None

    # Calculate Non-Truck Flow = Total Flow - Truck Flow
    processed_df['non_truck_flow'] = processed_df['total_flow'] - processed_df['truck_flow']

    # Handle any negative values
    negative_mask = processed_df['non_truck_flow'] < 0
    if negative_mask.sum() > 0:
        print(f"⚠️ Warning: {negative_mask.sum()} rows have negative non-truck flow values")
        processed_df.loc[negative_mask, 'non_truck_flow'] = 0

    # Add time-based features
    processed_df['time_index'] = range(len(processed_df))

    return processed_df

# %%
processed_df = process_traffic_data(combined_df)

# %%
display(processed_df)
print(processed_df.shape)
# Out:
#        total_flow  truck_flow  non_truck_flow  time_index
# 0            22.0         0.0            22.0           0
# 1            27.0         0.0            27.0           1
# 2            29.0         0.0            29.0           2
# 3            18.0         0.0            18.0           3
# 4            14.0         0.0            14.0           4
# ...           ...         ...             ...         ...
# 22819        32.0         0.0            32.0       22819
# 22820        24.0         0.0            24.0       22820
# 22821        29.0         0.0            29.0       22821
# 22822        26.0         0.0            26.0       22822
# 22823        22.0         0.0            22.0       22823
#
# [22824 rows x 4 columns]
# (22824, 4)

# %%
processed_df.columns
# Out:
# Index(['total_flow', 'truck_flow', 'non_truck_flow', 'time_index'], dtype='object')

# %%
from matplotlib import pyplot as plt
processed_df['non_truck_flow'].plot(kind='hist', bins=20, title='non_truck_flow')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
processed_df['truck_flow'].plot(kind='hist', bins=20, title='truck_flow')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
column_1_data = processed_df['truck_flow']
column_2_data = processed_df['non_truck_flow']

# %%
coloumn_1_data=np.array(column_1_data)
coloumn_2_data=np.array(column_2_data)

# %%
column1_data=coloumn_1_data.reshape(-1,1)
column2_data =coloumn_2_data.reshape(-1,1)

# %%
data = pd.concat([pd.DataFrame(column1_data), pd.DataFrame(column2_data)], axis=1)
print(data.shape)
# Out:
# (22824, 2)

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler((0,1))
scaled_data=scalar.fit_transform(data)

# %%
scaled_data.shape
# Out:
# (22824, 2)

# %%
display(scaled_data)
# Out:
# array([[0.        , 0.04932735],
#        [0.        , 0.06053812],
#        [0.        , 0.06502242],
#        ...,
#        [0.        , 0.06502242],
#        [0.        , 0.05829596],
#        [0.        , 0.04932735]])

# %%
def create_dataset(dataset, time_step):
    X, Y = [], []
    for i in range(len(dataset)-time_step):
        a = dataset[i:(i+time_step), :]
        X.append(a)
        Y.append(dataset[i + time_step, :])
    return np.array(X), np.array(Y)
time_step = 15
X, Y= create_dataset(scaled_data, time_step)
print(X.shape)
print(Y.shape)
# Out:
# (22809, 15, 2)
# (22809, 2)

# %%
X_train=X[:int(0.8*len(X))]
y_train = Y[:int(0.8*len(Y))].reshape(-1,2)
X_test = X[int(0.8*len(X)):]
y_test = Y[int(0.8*len(Y)):].reshape(-1,2)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (18247, 15, 2)
# (18247, 2)
# (4562, 15, 2)
# (4562, 2)

# %%
# !pip install keras-tcn
# Out:
# Collecting keras-tcn
#   Downloading keras_tcn-3.5.6-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras-tcn) (2.0.2)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-tcn) (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (1.74.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (3.14.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.5.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-tcn) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-tcn) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow->keras-tcn) (0.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow->keras-tcn) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->keras-tcn) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->keras-tcn) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard~=2.19.0->tensorflow->keras-tcn) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->keras-tcn) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-tcn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow->keras-tcn) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->keras-tcn) (0.1.2)
# Downloading keras_tcn-3.5.6-py3-none-any.whl (12 kB)
# Installing collected packages: keras-tcn
# Successfully installed keras-tcn-3.5.6

# %%
# from tensorflow.keras.layers import Input,Dense,Dropout
# from tensorflow.keras.models import Model
# from keras import regularizers
# from tcn import TCN
# inputs=Input(shape=(15,2))

# x = TCN(nb_filters=32, kernel_size=3, dilations=[1, 2, 4, 8,16] )(inputs)
# xx=Dropout(0.2)(x)
# x = TCN(nb_filters=32, kernel_size=3, dilations=[1, 2, 4, 8,16] )(xx)

# x=Dense(16,activation='relu',kernel_regularizer=regularizers.l2(0.001))(xx)
# outputs=Dense(2,kernel_regularizer=regularizers.l2(0.001))(x)
# model=Model(inputs=inputs,outputs=outputs)

# model.compile(optimizer='adam',loss='mae')
# model.summary()

# %%
from tensorflow.keras.layers import Input, Dense, Dropout, Add
from tensorflow.keras.models import Model
from keras import regularizers
from tcn import TCN

inputs = Input(shape=(15, 2))

x = TCN(nb_filters=32, kernel_size=3, dilations=[1, 2, 4, 8], return_sequences=True)(inputs)
xx = Dropout(0.15)(x)


tcn_out_for_residual = TCN(nb_filters=32, kernel_size=3, dilations=[1, 2, 4, 8], return_sequences=True)(xx)

x = Add()([xx, tcn_out_for_residual])


from tensorflow.keras.layers import GlobalAveragePooling1D

x = GlobalAveragePooling1D()(x)

x = Dense(16, activation='relu', kernel_regularizer=regularizers.l2(0.0001))(x)
outputs = Dense(2, kernel_regularizer=regularizers.l2(0.0001))(x)
model = Model(inputs=inputs, outputs=outputs)

model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 15, 2)     │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tcn (TCN)           │ (None, 15, 32)    │     22,048 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 15, 32)    │          0 │ tcn[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ tcn_1 (TCN)         │ (None, 15, 32)    │     24,832 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 15, 32)    │          0 │ dropout[0][0],    │
# │                     │                   │            │ tcn_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ add[0][0]         │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 16)        │        528 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 2)         │         34 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 47,442 (185.32 KB)
#  Trainable params: 47,442 (185.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history=model.fit(X_train,y_train,epochs=50,validation_split=0.15,verbose=1)
# Out:
# Epoch 1/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 24s 20ms/step - loss: 0.2462 - val_loss: 0.0045
# Epoch 2/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 0.0039 - val_loss: 0.0035
# Epoch 3/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.0035 - val_loss: 0.0038
# Epoch 4/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 5/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0031 - val_loss: 0.0032
# Epoch 6/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - loss: 0.0030 - val_loss: 0.0033
# Epoch 7/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0029 - val_loss: 0.0030
# Epoch 8/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0028 - val_loss: 0.0035
# Epoch 9/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0026 - val_loss: 0.0031
# Epoch 10/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0026 - val_loss: 0.0029
# Epoch 11/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.0026 - val_loss: 0.0035
# Epoch 12/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 12s 19ms/step - loss: 0.0025 - val_loss: 0.0033
# Epoch 13/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0024 - val_loss: 0.0036
# Epoch 14/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0024 - val_loss: 0.0031
# Epoch 15/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.0023 - val_loss: 0.0030
# Epoch 16/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0023 - val_loss: 0.0024
# Epoch 17/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.0022 - val_loss: 0.0028
# Epoch 18/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0021 - val_loss: 0.0025
# Epoch 19/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0021 - val_loss: 0.0031
# Epoch 20/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - loss: 0.0020 - val_loss: 0.0025
# Epoch 21/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 22/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0019 - val_loss: 0.0022
# Epoch 23/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0019 - val_loss: 0.0024
# Epoch 24/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0018 - val_loss: 0.0027
# Epoch 25/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0017 - val_loss: 0.0025
# Epoch 26/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 27/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 28/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0017 - val_loss: 0.0027
# Epoch 29/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0017 - val_loss: 0.0023
# Epoch 30/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - loss: 0.0016 - val_loss: 0.0029
# Epoch 31/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 32/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 33/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0016 - val_loss: 0.0023
# Epoch 34/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 35/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 36/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0015 - val_loss: 0.0022
# Epoch 37/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 38/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 39/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0015 - val_loss: 0.0023
# Epoch 40/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 41/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0016 - val_loss: 0.0031
# Epoch 42/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - loss: 0.0016 - val_loss: 0.0025
# Epoch 43/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 44/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0016 - val_loss: 0.0024
# Epoch 45/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0016 - val_loss: 0.0022
# Epoch 46/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - loss: 0.0016 - val_loss: 0.0021
# Epoch 47/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 48/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 49/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - loss: 0.0016 - val_loss: 0.0020
# Epoch 50/50
# 485/485 ━━━━━━━━━━━━━━━━━━━━ 8s 17ms/step - loss: 0.0015 - val_loss: 0.0024

# %%
model.save( 'tcn_model.keras')

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(loc='upper right')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.11/dist-packages/matplotlib/pyplot.py'>

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,mean_absolute_percentage_error
y_pred=model.predict(X_test)
test_predict=model.predict(X_test)
print(test_predict.shape)
predictions_original_scale = scalar.inverse_transform(test_predict)
y_test_original_scale = scalar.inverse_transform(y_test)
# mae=mean_absolute_error(predictions_original_scale,y_test_original_scale,)
# mse=np.sqrt(mean_squared_error(predictions_original_scale,y_test_original_scale,))
# mape=mean_absolute_percentage_error(predictions_original_scale,y_test_original_scale,)
# rmse=np.sqrt(mse)
# print(rmse)
# print(mse)
# print(mae)
# print(mape)
# Out:
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step
# 143/143 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# (4562, 2)
# 4.0732776139889735
# 16.591590520623704
# 8.128356367612568
# 0.6969811557372072

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error

plt.figure(figsize=(12, 6))

#  Truck Flow
plt.subplot(1, 2, 1)
plt.plot(y_test_original_scale[:, 0], label='Actual Truck Flow')
plt.plot(predictions_original_scale[:, 0], label='Predicted Truck Flow')
plt.title('Truck Flow: Actual vs. Predicted (Inverse Scaled)')
plt.xlabel('Time Steps')
plt.ylabel('Flow (Veh/5 Minutes)')
plt.legend()

# Non-Truck Flow
plt.subplot(1, 2, 2)
plt.plot(y_test_original_scale[:, 1], label='Actual Non-Truck Flow')
plt.plot(predictions_original_scale[:, 1], label='Predicted Non-Truck Flow')
plt.title('Non-Truck Flow: Actual vs. Predicted (Inverse Scaled)')
plt.xlabel('Time Steps')
plt.ylabel('Flow (Veh/5 Minutes)')
plt.legend()

plt.tight_layout()
plt.show()

# --- Truck Flow ---
actual_truck_flow = y_test_original_scale[:, 0]
predicted_truck_flow = predictions_original_scale[:, 0]

rmse_truck = np.sqrt(mean_squared_error(actual_truck_flow, predicted_truck_flow))
mae_truck = mean_absolute_error(actual_truck_flow, predicted_truck_flow)

# Masked MAPE
mask_truck = actual_truck_flow != 0
mape_truck = np.mean(
    np.abs((actual_truck_flow[mask_truck] - predicted_truck_flow[mask_truck]) / actual_truck_flow[mask_truck])
) * 100

print(f"--- Metrics for Truck Flow (Original Scale) ---")
print(f"RMSE: {rmse_truck:.4f}")
print(f"MAE: {mae_truck:.4f}")
print(f"MAPE (masked): {mape_truck:.2f}%")

# --- Non-Truck Flow ---
actual_non_truck_flow = y_test_original_scale[:, 1]
predicted_non_truck_flow = predictions_original_scale[:, 1]

rmse_non_truck = np.sqrt(mean_squared_error(actual_non_truck_flow, predicted_non_truck_flow))
mae_non_truck = mean_absolute_error(actual_non_truck_flow, predicted_non_truck_flow)

# Masked MAPE
mask_non_truck = actual_non_truck_flow != 0
mape_non_truck = np.mean(
    np.abs((actual_non_truck_flow[mask_non_truck] - predicted_non_truck_flow[mask_non_truck]) / actual_non_truck_flow[mask_non_truck])
) * 100

print(f"\n--- Metrics for Non-Truck Flow (Original Scale) ---")
print(f"RMSE: {rmse_non_truck:.4f}")
print(f"MAE: {mae_non_truck:.4f}")
print(f"MAPE (masked): {mape_non_truck:.2f}%")
# Out:
# --- Metrics for Truck Flow (Original Scale) ---
# RMSE: 1.0086
# MAE: 0.6287
# MAPE (masked): 36.42%
#
# --- Metrics for Non-Truck Flow (Original Scale) ---
# RMSE: 23.4424
# MAE: 15.6280
# MAPE (masked): 19.97%

# %%
# import tensorflow as tf

# converter = tf.lite.TFLiteConverter.from_keras_model(model)
# converter.optimizations = [tf.lite.Optimize.DEFAULT]
# converter.target_spec.supported_types = [tf.float16]
# converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
# converter._experimental_lower_tensor_list_ops = False
# tflite_model = converter.convert()

# # Save to .tflite file
# with open('tcn_model_quant.tflite', 'wb') as f:
#     f.write(tflite_model)
# Out:
# Saved artifact at '/tmp/tmp6hy89qsr'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 15, 2), dtype=tf.float32, name='keras_tensor')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   132186250179024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250182288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250182480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250181520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250181712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250180560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250181904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132186250182096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983746320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983747664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983746128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983748432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983747856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983746704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983749200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983749584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983749968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983750352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983748240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983751120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983750544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983750928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983749392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983747280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983750160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983751696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983751888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983752080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983749008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983752464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983752656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983752848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983750736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983753232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983753424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983754000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983753616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   132185983754384: TensorSpec(shape=(), dtype=tf.resource, name=None)

# %%
from google.colab import files

# Download the quantized model
files.download("tcn_model_quant.tflite")
